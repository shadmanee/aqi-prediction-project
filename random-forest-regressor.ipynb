# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
combined_data = pd.read_csv("datasets/feature_engineered_aqi_data_local.csv")

# %%
combined_data.head()
# Out:
#                         date   city  pm10  pm2_5  carbon_monoxide  \
# 0  2023-06-01 06:00:00+00:00  dhaka  51.3   34.1            369.0
# 1  2023-06-01 07:00:00+00:00  dhaka  50.2   32.5            381.0
# 2  2023-06-01 08:00:00+00:00  dhaka  51.3   32.9            397.0
# 3  2023-06-01 09:00:00+00:00  dhaka  58.4   37.8            410.0
# 4  2023-06-01 10:00:00+00:00  dhaka  71.5   46.9            405.0
#
#    nitrogen_dioxide  sulphur_dioxide  ozone  uv_index_clear_sky  uv_index  \
# 0              17.9              8.6   44.0                0.15      0.15
# 1              19.3             10.4   53.0                0.65      0.50
# 2              21.1             12.9   67.0                1.75      1.55
# 3              21.4             15.5   92.0                3.25      3.20
# 4              18.0             16.0  121.0                4.80      4.65
#
#    dust  aerosol_optical_depth     us_aqi  hour_sin      hour_cos  \
# 0   1.0                   1.17  152.57675  1.000000  6.123234e-17
# 1   1.0                   1.27  151.45615  0.965926 -2.588190e-01
# 2   1.0                   1.26  150.46272  0.866025 -5.000000e-01
# 3   1.0                   1.27  148.54167  0.707107 -7.071068e-01
# 4   1.0                   1.34  146.14584  0.500000 -8.660254e-01
#
#       month_sin  month_cos  day_of_week  year
# 0  1.224647e-16       -1.0            3  2023
# 1  1.224647e-16       -1.0            3  2023
# 2  1.224647e-16       -1.0            3  2023
# 3  1.224647e-16       -1.0            3  2023
# 4  1.224647e-16       -1.0            3  2023

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
combined_data['city_encoded'] = le.fit_transform(combined_data['city'])

# %%
X = combined_data[[col for col in combined_data.columns if col not in ["date", "us_aqi", "city"]]]
y = combined_data["us_aqi"]

# %%
from sklearn.model_selection import train_test_split
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.1, random_state=43)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.2, random_state=43)

# %% [markdown]
# ## RANDOM FOREST REGRESSOR

# %%
from sklearn.ensemble import RandomForestRegressor
forest = RandomForestRegressor()
forest.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
f'Coefficient of determination R^2 on train set {forest.score(X_train, y_train)}'
# must be close to 1, 1 is perfect fit
# Out:
# 'Coefficient of determination R^2 on train set 0.9906431879915455'

# %%
f'Coefficient of determination R^2 on test set {forest.score(X_val, y_val)}'
# Out:
# 'Coefficient of determination R^2 on test set 0.9334758726883483'

# %%
from sklearn.model_selection import cross_val_score
score = cross_val_score(forest, X, y, cv = 5)

# %%
score.mean()
# Out:
# np.float64(0.8606330902954014)

# %%
pred = forest.predict(X_test)

# %%
sns.distplot(y_test - pred)
# Out:
# C:\Users\stasn\AppData\Local\Temp\ipykernel_3424\2485339681.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test - pred)
# <Axes: xlabel='us_aqi', ylabel='Density'>

# %%
from sklearn import metrics
print(f"Mean Abs Error: {metrics.mean_absolute_error(y_test, pred)}")
print(f"Mean Sq Error: {metrics.mean_squared_error(y_test, pred)}")
print(f"Root Mean Error: {np.sqrt(metrics.mean_squared_error(y_test, pred))}")
# Out:
# Mean Abs Error: 8.270982131369527
# Mean Sq Error: 148.9881875764701
# Root Mean Error: 12.206071750422824

# %%
import pickle
pickle.dump(forest, open('models/random-forest.pkl', 'wb'))
